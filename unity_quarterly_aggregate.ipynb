# %%
from database.strategy import Strategy
from database.sec import SEC
from database.market import Market
from transformer.date_transformer import DateTransformer
from transformer.column_transformer import ColumnTransformer
from transformer.model_transformer import ModelTransformer
from transformer.product_transformer import ProductTransformer
from transformer.predictor_transformer import PredictorTransformer
from preprocessor.model_preprocessor import ModelPreprocessor
from preprocessor.predictor_preprocessor import PredictorPreprocessor
from modeler.modeler import Modeler as sp
from utils.date_utils import DateUtils
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta, timezone
from tqdm import tqdm
import math
from IPython.core.debugger import set_trace

# %%
## Loading Constants
start = "2008-01-01"
end = datetime(2021,1,1).strftime("%Y-%m-%d")
# Loading Databases
strat_db = Strategy("unity")
market = Market()
sec = SEC("sec")
market.connect()
tickers = market.retrieve_data("sp500").sort_values("Symbol")
market.close()
quarterly_range = range(1,5)
yearly_range = range(2014,2021)
model_range = range(len(tickers["Symbol"]))
datasets = ["pdr"
#             ,"tiingo"
#             ,"finnhub"
           ]

# %%
sims = []
gap = 365
year_gap = int(gap/365)
quarter_gap = int(gap/90)
training_years = 4
training_days = 100
sec.connect()
strat_db.connect()
market.connect()
for dataset in datasets:
#     strat_db.drop_table("{}_fundamental_quarterly_sim".format(dataset))
    strat_db.drop_table("{}_fundamental_quarterly_sim_errors")
    quarterly_classification_data = market.retrieve_data("dataset_{}_quarter_classification".format(dataset))
    quarterly_regression_data = market.retrieve_data("dataset_{}_quarter_regression".format(dataset))
#     strat_db.drop_table("{}_price_quarterly_sim".format(dataset))
    strat_db.drop_table("{}_price_quarterly_sim_errors".format(dataset))
    for year in tqdm(yearly_range):
        for quarter in tqdm(quarterly_range):
            try:
                ## Setting Up
                print(year,quarter)
                date_ranges = DateUtils.create_quarterly_training_range_rec(year,quarter,training_years,gap)
                training_start,training_end,prediction_start,prediction_end = date_ranges
                dates = pd.to_datetime(date_ranges)
                quarters = [x.quarter for x in dates]
                years = [x.year for x in dates]
                print(date_ranges)
                ### switch to all tickers
                for i in model_range:
                    try:
                        ticker = tickers.iloc[i]["Symbol"].replace(".","-")
                        if ticker in quarterly_regression_data.columns:
                            cik = int(tickers.iloc[i]["CIK"].item())
                            price = market.retrieve_price_data("{}_prices".format(dataset),ticker)
                            if dataset == "pdr":
                                price = ColumnTransformer.rename_columns(price," ")
                            else:
                                price = ColumnTransformer.rename_columns(price,"")
                            price = DateTransformer.convert_to_date(dataset,price,"date")
                            filing = sec.retrieve_filing_data(cik)
                            mt = ModelTransformer(ticker,training_start,training_end,gap)
                            pt = ModelTransformer(ticker,prediction_start,prediction_end,gap)
                            mr = ModelPreprocessor(ticker)
                            prot = ProductTransformer(ticker,prediction_start,prediction_end)
                            ## regression_model
                            rfd = mt.fundamental_merge(price.copy(),filing.copy(),True,classify=False)
                            factors = rfd.columns 
                            refined = mr.fundamental_preprocess(rfd.copy())
                            rfr = sp.regression(refined,ranked=False,tf=False)
                            cfd = mt.fundamental_merge(price.copy(),filing.copy(),True,classify=True)
                            refined = mr.fundamental_preprocess(cfd.copy())
                            cfr = sp.classification(refined,tf=False)
                            fundamental_results = pd.DataFrame([cfr
                                                                ,rfr])
                            product_refineds = []
                            product_qpds = []
                            for i in range(len(fundamental_results)):
                                fundamental_result = fundamental_results.iloc[i]
                                if fundamental_result["model_type"] == "regression":
                                    fundamental_data = pt.fundamental_merge_rec(filing.copy(),False,factors)
                                else:
                                    fundamental_data = pt.fundamental_merge_rec(filing.copy(),True,factors)
                                product_refined = mr.fundamental_preprocess_rec(fundamental_data.copy())
                                product_refineds.append(product_refined)
                            sim = prot.merge_quarterlies_v2(product_refineds,fundamental_results,year,quarter,"fundamental",gap)
                            strat_db.store_data("{}_fundamental_quarterly_sim".format(dataset),pd.DataFrame([sim]))
                    except Exception as e:
                        message = {"status":"quarterly modeling","ticker":ticker,"year":str(year),"quarter":str(quarter),"message":str(e)}
                        print(message)
                        strat_db.store_data("fundamental_quarterly_sim_errors",pd.DataFrame([message]))
            except Exception as e:
                print(year,quarter,str(e))
sec.close()
market.close()
strat_db.close()
# Out:
#   0%|                                                                                                                                                | 0/7 [00:00<?, ?it/s]
#   0%|                                                                                                                                                | 0/4 [00:00<?, ?it/s]
# 2014 1
# ['2010-01-01', '2013-12-31', '2014-01-01', '2014-03-31']
# [13:01:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'ALB', 'year': '2014', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'ALLE', 'year': '2014', 'quarter': '1', 'message': 'With n_samples=1, test_size=0.25 and train_size=0.75, the resulting train set will be empty. Adjust any of the aforementioned parameters.'}
# {'status': 'quarterly modeling', 'ticker': 'AMC', 'year': '2014', 'quarter': '1', 'message': 'With n_samples=1, test_size=0.25 and train_size=0.75, the resulting train set will be empty. Adjust any of the aforementioned parameters.'}
# {'status': 'quarterly modeling', 'ticker': 'AMCR', 'year': '2014', 'quarter': '1', 'message': 'single positional indexer is out-of-bounds'}
# [13:02:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'ANET', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 85)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'APA', 'year': '2014', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# [13:03:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'BRK-B', 'year': '2014', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# [13:05:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'CARR', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 148)) while a minimum of 1 is required.'}
# [13:06:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:06:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'CCI', 'year': '2014', 'quarter': '1', 'message': 'single positional indexer is out-of-bounds'}
# {'status': 'quarterly modeling', 'ticker': 'CCL', 'year': '2014', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CDW', 'year': '2014', 'quarter': '1', 'message': 'single positional indexer is out-of-bounds'}
# [13:06:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'CF', 'year': '2014', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CFG', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 172)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'CHTR', 'year': '2014', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# [13:06:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:07:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:08:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'CTLT', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 100)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'CTVA', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 115)) while a minimum of 1 is required.'}
# [13:09:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:09:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:10:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'DOW', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 144)) while a minimum of 1 is required.'}
# [13:11:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:12:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:12:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'ETSY', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 52)) while a minimum of 1 is required.'}
# [13:13:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'EXPE', 'year': '2014', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'FANG', 'year': '2014', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'FOX', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 67)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'FOXA', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 67)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'FRC', 'year': '2014', 'quarter': '1', 'message': "'filed'"}
# [13:15:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'FTV', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 66)) while a minimum of 1 is required.'}
# [13:16:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:16:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'GS', 'year': '2014', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'HIG', 'year': '2014', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'HLT', 'year': '2014', 'quarter': '1', 'message': 'With n_samples=1, test_size=0.25 and train_size=0.75, the resulting train set will be empty. Adjust any of the aforementioned parameters.'}
# {'status': 'quarterly modeling', 'ticker': 'HPE', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 68)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'HPQ', 'year': '2014', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# [13:18:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:18:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:18:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'INFO', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 96)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'IR', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 108)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'KEYS', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 32)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'KHC', 'year': '2014', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# [13:21:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:21:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:22:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:22:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'LW', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 83)) while a minimum of 1 is required.'}
# [13:23:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:23:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:24:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:24:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:26:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:26:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'NI', 'year': '2014', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'NLSN', 'year': '2014', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# [13:27:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'NWS', 'year': '2014', 'quarter': '1', 'message': 'single positional indexer is out-of-bounds'}
# {'status': 'quarterly modeling', 'ticker': 'NWSA', 'year': '2014', 'quarter': '1', 'message': 'single positional indexer is out-of-bounds'}
# {'status': 'quarterly modeling', 'ticker': 'OTIS', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 135)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'PAYC', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 56)) while a minimum of 1 is required.'}
# [13:30:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:30:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'PYPL', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 58)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'QRVO', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 15)) while a minimum of 1 is required.'}
# [13:31:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:31:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'SBAC', 'year': '2014', 'quarter': '1', 'message': 'single positional indexer is out-of-bounds'}
# [13:32:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'SO', 'year': '2014', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# [13:33:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:33:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'SYF', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 103)) while a minimum of 1 is required.'}
# [13:34:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'TMUS', 'year': '2014', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'TSN', 'year': '2014', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'TWTR', 'year': '2014', 'quarter': '1', 'message': 'With n_samples=1, test_size=0.25 and train_size=0.75, the resulting train set will be empty. Adjust any of the aforementioned parameters.'}
# {'status': 'quarterly modeling', 'ticker': 'UA', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 40)) while a minimum of 1 is required.'}
# [13:35:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:36:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'VNT', 'year': '2014', 'quarter': '1', 'message': "'filed'"}
# {'status': 'quarterly modeling', 'ticker': 'WRK', 'year': '2014', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 146)) while a minimum of 1 is required.'}
# [13:39:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
#  25%|█████████████████████████████████                                                                                                   | 1/4 [41:14<2:03:42, 2474.21s/it]
# {'status': 'quarterly modeling', 'ticker': 'ZTS', 'year': '2014', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# 2014 2
# ['2010-04-01', '2014-03-31', '2014-04-01', '2014-06-30']
# {'status': 'quarterly modeling', 'ticker': 'ALB', 'year': '2014', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'ALLE', 'year': '2014', 'quarter': '2', 'message': 'single positional indexer is out-of-bounds'}
# {'status': 'quarterly modeling', 'ticker': 'AMC', 'year': '2014', 'quarter': '2', 'message': 'single positional indexer is out-of-bounds'}
# [13:43:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'ANET', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 85)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'APA', 'year': '2014', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# [13:44:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'BAX', 'year': '2014', 'quarter': '2', 'message': 'single positional indexer is out-of-bounds'}
# [13:45:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:46:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'BRK-B', 'year': '2014', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CARR', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 148)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'CCL', 'year': '2014', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CF', 'year': '2014', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CFG', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 172)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'CHTR', 'year': '2014', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# [13:48:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'CTLT', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 100)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'CTVA', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 115)) while a minimum of 1 is required.'}
# [13:50:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:51:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'DOW', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 144)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'EBAY', 'year': '2014', 'quarter': '2', 'message': 'single positional indexer is out-of-bounds'}
# {'status': 'quarterly modeling', 'ticker': 'ETSY', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 52)) while a minimum of 1 is required.'}
# [13:54:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'EXPE', 'year': '2014', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'FANG', 'year': '2014', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# [13:55:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'FOX', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 67)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'FOXA', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 67)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'FRC', 'year': '2014', 'quarter': '2', 'message': "'filed'"}
# [13:56:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'FTV', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 66)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'GIS', 'year': '2014', 'quarter': '2', 'message': 'single positional indexer is out-of-bounds'}
# [13:57:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [13:57:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'GS', 'year': '2014', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'HIG', 'year': '2014', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'HLT', 'year': '2014', 'quarter': '2', 'message': 'single positional indexer is out-of-bounds'}
# {'status': 'quarterly modeling', 'ticker': 'HPE', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 68)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'HPQ', 'year': '2014', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# [13:59:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'INFO', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 96)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'IQV', 'year': '2014', 'quarter': '2', 'message': 'single positional indexer is out-of-bounds'}
# {'status': 'quarterly modeling', 'ticker': 'IR', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 108)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'KEYS', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 32)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'KHC', 'year': '2014', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# [14:02:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'LW', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 83)) while a minimum of 1 is required.'}
# [14:04:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [14:05:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'NI', 'year': '2014', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'NLSN', 'year': '2014', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'NWS', 'year': '2014', 'quarter': '2', 'message': 'single positional indexer is out-of-bounds'}
# {'status': 'quarterly modeling', 'ticker': 'OTIS', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 135)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'PAYC', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 56)) while a minimum of 1 is required.'}
# [14:11:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'PYPL', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 58)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'QRVO', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 15)) while a minimum of 1 is required.'}
# [14:12:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'SO', 'year': '2014', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# [14:14:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'SYF', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 103)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'TMUS', 'year': '2014', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'TSN', 'year': '2014', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'TWTR', 'year': '2014', 'quarter': '2', 'message': 'single positional indexer is out-of-bounds'}
# {'status': 'quarterly modeling', 'ticker': 'UA', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 40)) while a minimum of 1 is required.'}
# [14:18:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'VNT', 'year': '2014', 'quarter': '2', 'message': "'filed'"}
# [14:19:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [14:20:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'WRK', 'year': '2014', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 146)) while a minimum of 1 is required.'}
# [14:22:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
#  50%|█████████████████████████████████████████████████████████████████                                                                 | 2/4 [1:23:30<1:23:05, 2492.94s/it]
# {'status': 'quarterly modeling', 'ticker': 'ZTS', 'year': '2014', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# 2014 3
# ['2010-07-01', '2014-06-30', '2014-07-01', '2014-09-30']
# [14:23:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [14:23:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [14:24:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'ALB', 'year': '2014', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'ALLE', 'year': '2014', 'quarter': '3', 'message': 'single positional indexer is out-of-bounds'}
# {'status': 'quarterly modeling', 'ticker': 'AMC', 'year': '2014', 'quarter': '3', 'message': 'single positional indexer is out-of-bounds'}
# [14:25:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'ANET', 'year': '2014', 'quarter': '3', 'message': 'With n_samples=1, test_size=0.25 and train_size=0.75, the resulting train set will be empty. Adjust any of the aforementioned parameters.'}
# {'status': 'quarterly modeling', 'ticker': 'APA', 'year': '2014', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# [14:27:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [14:28:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [14:29:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'BRK-B', 'year': '2014', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CARR', 'year': '2014', 'quarter': '3', 'message': 'Found array with 0 sample(s) (shape=(0, 148)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'CCL', 'year': '2014', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CF', 'year': '2014', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CFG', 'year': '2014', 'quarter': '3', 'message': 'Found array with 0 sample(s) (shape=(0, 172)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'CHTR', 'year': '2014', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# [14:32:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'CLX', 'year': '2014', 'quarter': '3', 'message': 'single positional indexer is out-of-bounds'}
# {'status': 'quarterly modeling', 'ticker': 'CTLT', 'year': '2014', 'quarter': '3', 'message': 'Found array with 0 sample(s) (shape=(0, 100)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'CTVA', 'year': '2014', 'quarter': '3', 'message': 'Found array with 0 sample(s) (shape=(0, 115)) while a minimum of 1 is required.'}
# [14:35:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [14:35:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'DOW', 'year': '2014', 'quarter': '3', 'message': 'Found array with 0 sample(s) (shape=(0, 144)) while a minimum of 1 is required.'}
# [14:37:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'ETSY', 'year': '2014', 'quarter': '3', 'message': 'Found array with 0 sample(s) (shape=(0, 52)) while a minimum of 1 is required.'}
# [14:39:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'EXPE', 'year': '2014', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'FANG', 'year': '2014', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# [14:41:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'FOX', 'year': '2014', 'quarter': '3', 'message': 'Found array with 0 sample(s) (shape=(0, 67)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'FOXA', 'year': '2014', 'quarter': '3', 'message': 'Found array with 0 sample(s) (shape=(0, 67)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'FRC', 'year': '2014', 'quarter': '3', 'message': "'filed'"}
# [14:41:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'FTV', 'year': '2014', 'quarter': '3', 'message': 'Found array with 0 sample(s) (shape=(0, 66)) while a minimum of 1 is required.'}
# [14:42:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [14:42:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'GS', 'year': '2014', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'HIG', 'year': '2014', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'HLT', 'year': '2014', 'quarter': '3', 'message': 'single positional indexer is out-of-bounds'}
# {'status': 'quarterly modeling', 'ticker': 'HPE', 'year': '2014', 'quarter': '3', 'message': 'Found array with 0 sample(s) (shape=(0, 68)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'HPQ', 'year': '2014', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'INFO', 'year': '2014', 'quarter': '3', 'message': 'With n_samples=1, test_size=0.25 and train_size=0.75, the resulting train set will be empty. Adjust any of the aforementioned parameters.'}
# {'status': 'quarterly modeling', 'ticker': 'IQV', 'year': '2014', 'quarter': '3', 'message': 'single positional indexer is out-of-bounds'}
# {'status': 'quarterly modeling', 'ticker': 'IR', 'year': '2014', 'quarter': '3', 'message': 'Found array with 0 sample(s) (shape=(0, 108)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'KEYS', 'year': '2014', 'quarter': '3', 'message': 'Found array with 0 sample(s) (shape=(0, 32)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'KHC', 'year': '2014', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# [14:49:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'LW', 'year': '2014', 'quarter': '3', 'message': 'Found array with 0 sample(s) (shape=(0, 83)) while a minimum of 1 is required.'}
# [14:51:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'NI', 'year': '2014', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'NLSN', 'year': '2014', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'OTIS', 'year': '2014', 'quarter': '3', 'message': 'Found array with 0 sample(s) (shape=(0, 135)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'PAYC', 'year': '2014', 'quarter': '3', 'message': 'With n_samples=1, test_size=0.25 and train_size=0.75, the resulting train set will be empty. Adjust any of the aforementioned parameters.'}
# [14:58:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'PYPL', 'year': '2014', 'quarter': '3', 'message': 'Found array with 0 sample(s) (shape=(0, 58)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'QRVO', 'year': '2014', 'quarter': '3', 'message': 'Found array with 0 sample(s) (shape=(0, 15)) while a minimum of 1 is required.'}
# [15:00:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [15:00:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'RSG', 'year': '2014', 'quarter': '3', 'message': 'single positional indexer is out-of-bounds'}
# {'status': 'quarterly modeling', 'ticker': 'SO', 'year': '2014', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# [15:02:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [15:02:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'SYF', 'year': '2014', 'quarter': '3', 'message': 'Found array with 0 sample(s) (shape=(0, 103)) while a minimum of 1 is required.'}
# [15:03:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'TMUS', 'year': '2014', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'TSN', 'year': '2014', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'UA', 'year': '2014', 'quarter': '3', 'message': 'Found array with 0 sample(s) (shape=(0, 40)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'VNT', 'year': '2014', 'quarter': '3', 'message': "'filed'"}
# [15:07:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [15:07:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'WRK', 'year': '2014', 'quarter': '3', 'message': 'Found array with 0 sample(s) (shape=(0, 146)) while a minimum of 1 is required.'}
#  75%|███████████████████████████████████████████████████████████████████████████████████████████████████                                 | 3/4 [2:11:20<43:25, 2606.00s/it]
# {'status': 'quarterly modeling', 'ticker': 'ZTS', 'year': '2014', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# 2014 4
# ['2010-10-01', '2014-09-30', '2014-10-01', '2014-12-31']
# {'status': 'quarterly modeling', 'ticker': 'ALB', 'year': '2014', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'ALLE', 'year': '2014', 'quarter': '4', 'message': 'single positional indexer is out-of-bounds'}
# [15:13:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'ANET', 'year': '2014', 'quarter': '4', 'message': 'single positional indexer is out-of-bounds'}
# {'status': 'quarterly modeling', 'ticker': 'APA', 'year': '2014', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# [15:15:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'BRK-B', 'year': '2014', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CARR', 'year': '2014', 'quarter': '4', 'message': 'Found array with 0 sample(s) (shape=(0, 148)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'CCL', 'year': '2014', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CF', 'year': '2014', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CFG', 'year': '2014', 'quarter': '4', 'message': 'With n_samples=1, test_size=0.25 and train_size=0.75, the resulting train set will be empty. Adjust any of the aforementioned parameters.'}
# {'status': 'quarterly modeling', 'ticker': 'CHTR', 'year': '2014', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# [15:19:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'CTLT', 'year': '2014', 'quarter': '4', 'message': 'With n_samples=1, test_size=0.25 and train_size=0.75, the resulting train set will be empty. Adjust any of the aforementioned parameters.'}
# {'status': 'quarterly modeling', 'ticker': 'CTVA', 'year': '2014', 'quarter': '4', 'message': 'Found array with 0 sample(s) (shape=(0, 115)) while a minimum of 1 is required.'}
# [15:22:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'DOW', 'year': '2014', 'quarter': '4', 'message': 'Found array with 0 sample(s) (shape=(0, 144)) while a minimum of 1 is required.'}
# [15:23:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'ETSY', 'year': '2014', 'quarter': '4', 'message': 'Found array with 0 sample(s) (shape=(0, 52)) while a minimum of 1 is required.'}
# [15:25:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'EXPE', 'year': '2014', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'FANG', 'year': '2014', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# [15:26:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'FOX', 'year': '2014', 'quarter': '4', 'message': 'Found array with 0 sample(s) (shape=(0, 67)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'FOXA', 'year': '2014', 'quarter': '4', 'message': 'Found array with 0 sample(s) (shape=(0, 67)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'FRC', 'year': '2014', 'quarter': '4', 'message': "'filed'"}
# [15:27:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'FTV', 'year': '2014', 'quarter': '4', 'message': 'Found array with 0 sample(s) (shape=(0, 66)) while a minimum of 1 is required.'}
# [15:28:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [15:28:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'GS', 'year': '2014', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'HIG', 'year': '2014', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'HPE', 'year': '2014', 'quarter': '4', 'message': 'Found array with 0 sample(s) (shape=(0, 68)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'HPQ', 'year': '2014', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'IR', 'year': '2014', 'quarter': '4', 'message': 'Found array with 0 sample(s) (shape=(0, 108)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'KEYS', 'year': '2014', 'quarter': '4', 'message': 'Found array with 0 sample(s) (shape=(0, 32)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'KHC', 'year': '2014', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# [15:34:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'LW', 'year': '2014', 'quarter': '4', 'message': 'Found array with 0 sample(s) (shape=(0, 83)) while a minimum of 1 is required.'}
# [15:36:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [15:36:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'NI', 'year': '2014', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'NLSN', 'year': '2014', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'OTIS', 'year': '2014', 'quarter': '4', 'message': 'Found array with 0 sample(s) (shape=(0, 135)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'PAYC', 'year': '2014', 'quarter': '4', 'message': 'single positional indexer is out-of-bounds'}
# [15:41:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'PYPL', 'year': '2014', 'quarter': '4', 'message': 'Found array with 0 sample(s) (shape=(0, 58)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'QRVO', 'year': '2014', 'quarter': '4', 'message': 'Found array with 0 sample(s) (shape=(0, 15)) while a minimum of 1 is required.'}
# [15:43:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'SO', 'year': '2014', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# [15:45:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [15:45:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [15:45:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'SYF', 'year': '2014', 'quarter': '4', 'message': 'With n_samples=1, test_size=0.25 and train_size=0.75, the resulting train set will be empty. Adjust any of the aforementioned parameters.'}
# {'status': 'quarterly modeling', 'ticker': 'TMUS', 'year': '2014', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'TSN', 'year': '2014', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'TWTR', 'year': '2014', 'quarter': '4', 'message': 'single positional indexer is out-of-bounds'}
# {'status': 'quarterly modeling', 'ticker': 'UA', 'year': '2014', 'quarter': '4', 'message': 'Found array with 0 sample(s) (shape=(0, 40)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'VNT', 'year': '2014', 'quarter': '4', 'message': "'filed'"}
# [15:50:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [15:51:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'WRK', 'year': '2014', 'quarter': '4', 'message': 'Found array with 0 sample(s) (shape=(0, 146)) while a minimum of 1 is required.'}
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [2:53:23<00:00, 2600.80s/it]
#  14%|██████████████████▎                                                                                                             | 1/7 [2:53:23<17:20:19, 10403.22s/it]
#   0%|                                                                                                                                                | 0/4 [00:00<?, ?it/s]
# {'status': 'quarterly modeling', 'ticker': 'ZTS', 'year': '2014', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# 2015 1
# ['2011-01-03', '2014-12-31', '2015-01-01', '2015-03-31']
# {'status': 'quarterly modeling', 'ticker': 'ALB', 'year': '2015', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# [15:55:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'APA', 'year': '2015', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# [15:56:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'BRK-B', 'year': '2015', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CARR', 'year': '2015', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 148)) while a minimum of 1 is required.'}
# {'status': 'quarterly modeling', 'ticker': 'CCL', 'year': '2015', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CF', 'year': '2015', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# ...
# {'status': 'quarterly modeling', 'ticker': 'EXPE', 'year': '2020', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'FANG', 'year': '2020', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'FRC', 'year': '2020', 'quarter': '1', 'message': "'filed'"}
# {'status': 'quarterly modeling', 'ticker': 'GS', 'year': '2020', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'HIG', 'year': '2020', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'HPQ', 'year': '2020', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'KHC', 'year': '2020', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# [04:10:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'NI', 'year': '2020', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'NLSN', 'year': '2020', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'OTIS', 'year': '2020', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 135)) while a minimum of 1 is required.'}
# [04:16:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'SO', 'year': '2020', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# [04:17:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [04:18:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'TMUS', 'year': '2020', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'TSN', 'year': '2020', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# [04:19:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'VNT', 'year': '2020', 'quarter': '1', 'message': "'filed'"}
# [04:21:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [04:21:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'WRK', 'year': '2020', 'quarter': '1', 'message': 'Found array with 0 sample(s) (shape=(0, 146)) while a minimum of 1 is required.'}
# [04:22:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
#  25%|█████████████████████████████████                                                                                                   | 1/4 [29:19<1:27:59, 1759.78s/it]
# {'status': 'quarterly modeling', 'ticker': 'ZTS', 'year': '2020', 'quarter': '1', 'message': 'at least one array or dtype is required'}
# 2020 2
# ['2016-04-01', '2020-03-31', '2020-04-01', '2020-06-30']
# {'status': 'quarterly modeling', 'ticker': 'ALB', 'year': '2020', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'APA', 'year': '2020', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'BRK-B', 'year': '2020', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CARR', 'year': '2020', 'quarter': '2', 'message': 'single positional indexer is out-of-bounds'}
# {'status': 'quarterly modeling', 'ticker': 'CCL', 'year': '2020', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CF', 'year': '2020', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CHTR', 'year': '2020', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'DIS', 'year': '2020', 'quarter': '2', 'message': 'single positional indexer is out-of-bounds'}
# {'status': 'quarterly modeling', 'ticker': 'EXPE', 'year': '2020', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'FANG', 'year': '2020', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# [04:33:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'FRC', 'year': '2020', 'quarter': '2', 'message': "'filed'"}
# {'status': 'quarterly modeling', 'ticker': 'GS', 'year': '2020', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'HIG', 'year': '2020', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'HPQ', 'year': '2020', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'KHC', 'year': '2020', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'NI', 'year': '2020', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'NLSN', 'year': '2020', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'OTIS', 'year': '2020', 'quarter': '2', 'message': 'single positional indexer is out-of-bounds'}
# [04:43:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'SO', 'year': '2020', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'TMUS', 'year': '2020', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'TSN', 'year': '2020', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'VNT', 'year': '2020', 'quarter': '2', 'message': "'filed'"}
# [04:50:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'WRK', 'year': '2020', 'quarter': '2', 'message': 'Found array with 0 sample(s) (shape=(0, 146)) while a minimum of 1 is required.'}
# [04:51:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
#  50%|███████████████████████████████████████████████████████████████████                                                                   | 2/4 [58:45<58:43, 1761.59s/it]
# {'status': 'quarterly modeling', 'ticker': 'ZTS', 'year': '2020', 'quarter': '2', 'message': 'at least one array or dtype is required'}
# 2020 3
# ['2016-07-01', '2020-06-30', '2020-07-01', '2020-09-30']
# [04:52:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'ALB', 'year': '2020', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'APA', 'year': '2020', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# [04:55:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'BRK-B', 'year': '2020', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CARR', 'year': '2020', 'quarter': '3', 'message': 'single positional indexer is out-of-bounds'}
# {'status': 'quarterly modeling', 'ticker': 'CCL', 'year': '2020', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CF', 'year': '2020', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CHTR', 'year': '2020', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# [04:58:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'EXPE', 'year': '2020', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'FANG', 'year': '2020', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'FRC', 'year': '2020', 'quarter': '3', 'message': "'filed'"}
# {'status': 'quarterly modeling', 'ticker': 'GS', 'year': '2020', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'HIG', 'year': '2020', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'HPQ', 'year': '2020', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'KHC', 'year': '2020', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# [05:11:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'NI', 'year': '2020', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'NLSN', 'year': '2020', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'OTIS', 'year': '2020', 'quarter': '3', 'message': 'single positional indexer is out-of-bounds'}
# {'status': 'quarterly modeling', 'ticker': 'SO', 'year': '2020', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# [05:16:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'TMUS', 'year': '2020', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'TSN', 'year': '2020', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'VNT', 'year': '2020', 'quarter': '3', 'message': "'filed'"}
# [05:19:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# [05:20:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'WRK', 'year': '2020', 'quarter': '3', 'message': 'Found array with 0 sample(s) (shape=(0, 146)) while a minimum of 1 is required.'}
# [05:21:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
#  75%|███████████████████████████████████████████████████████████████████████████████████████████████████                                 | 3/4 [1:28:05<29:21, 1761.23s/it]
# {'status': 'quarterly modeling', 'ticker': 'ZTS', 'year': '2020', 'quarter': '3', 'message': 'at least one array or dtype is required'}
# 2020 4
# ['2016-10-03', '2020-09-30', '2020-10-01', '2020-12-31']
# [05:22:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'ALB', 'year': '2020', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'APA', 'year': '2020', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# [05:25:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'BRK-B', 'year': '2020', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CCL', 'year': '2020', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CF', 'year': '2020', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'CHTR', 'year': '2020', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'DOW', 'year': '2020', 'quarter': '4', 'message': 'single positional indexer is out-of-bounds'}
# [05:29:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'EXPE', 'year': '2020', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'FANG', 'year': '2020', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'FRC', 'year': '2020', 'quarter': '4', 'message': "'filed'"}
# {'status': 'quarterly modeling', 'ticker': 'GS', 'year': '2020', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'HIG', 'year': '2020', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'HPQ', 'year': '2020', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# [05:35:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'KHC', 'year': '2020', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# [05:39:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'NI', 'year': '2020', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'NLSN', 'year': '2020', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'SO', 'year': '2020', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'TMUS', 'year': '2020', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'TSN', 'year': '2020', 'quarter': '4', 'message': 'at least one array or dtype is required'}
# {'status': 'quarterly modeling', 'ticker': 'VNT', 'year': '2020', 'quarter': '4', 'message': "'filed'"}
# [05:49:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1190: Empty dataset at worker: 0
# {'status': 'quarterly modeling', 'ticker': 'WRK', 'year': '2020', 'quarter': '4', 'message': 'Found array with 0 sample(s) (shape=(0, 146)) while a minimum of 1 is required.'}
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [1:57:28<00:00, 1762.02s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7/7 [16:51:43<00:00, 8671.88s/it]
# {'status': 'quarterly modeling', 'ticker': 'ZTS', 'year': '2020', 'quarter': '4', 'message': 'at least one array or dtype is required'}
